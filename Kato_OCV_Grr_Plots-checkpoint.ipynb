# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
celldata = pd.read_csv('C:\\Users\\zackg\\Desktop\\Kato_OCV_Grr\\celldata.csv')

# %%
celldata.CELL1
# Out:
# 0     3.283671
# 1     3.283672
# 2     3.283666
# 3     3.283665
# 4     3.283663
#         ...
# 75    3.283612
# 76    3.283608
# 77    3.283610
# 78    3.283610
# 79    3.283607
# Name: CELL1, Length: 80, dtype: float64

# %%
plt.violinplot([celldata.CELL1], showmeans=True, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e2b9f83be0>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x1e2b9f27310>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e2b9f910d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e2b9f913d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1e2b9f916d0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x1e2b9f919d0>}

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9, 9))

axs[0].violinplot([celldata.CELL1], showmeans=True, showmedians=True)
axs[1].violinplot([celldata.CELL2], showmeans=True, showmedians=True)
axs[2].violinplot([celldata.CELL3], showmeans=True, showmedians=True)
axs[3].violinplot([celldata.CELL4], showmeans=True, showmedians=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-69d324571577> in <module>
#       1 fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(9, 9))
#       2
# ----> 3 axs[0].violinplot([celldata.CELL1], showmeans=True, showmedians=True)
#       4 axs[1].violinplot([celldata.CELL2],showmeans=True, showmedians=True)
#       5 axs[2].violinplot([celldata.CELL3], showmeans=True, showmedians=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'violinplot'
